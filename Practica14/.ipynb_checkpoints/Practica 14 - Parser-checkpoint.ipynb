# %%
# PRÁCTICA 14 - Parser
# María José Medina Hernández

# %%
# !pip3 install pdftotext
# Out:
# Requirement already satisfied: pdftotext in /home/maria/mambaforge/lib/python3.9/site-packages (2.2.2)

# %%
# Imports
import pdftotext
import re

# %%
def load_pdf(pdf_path):
    with open(pdf_path, "rb") as input_file:
        pdf = pdftotext.PDF(input_file)
    return pdf

# %%
pdf = load_pdf("BORME-A-2019-232-02.pdf")

# %%
def extract_concepts(paragraph):
    """
    Extracts the different concepts from an entry of the BORME pdf.
    
    Params
    -------
    paragraph : string
        The paragraph of each entry (eg. Otros conceptos: Declaración de insolvencia total por importe de 11.137,78 euros. Datos registrales. T 982, L 746, F 66, S 8, H AB
26079, I/A 2 (25.11.19).).

    Return
    -------
    ceses : string
        Termination of a position (eg. Adm. Unico: LLORENTE MERINO RAFAEL.).
    """
    date =
    # Declare variables
    ceses = ""
    nombramientos = ""
    ampliacion = ""
    domicilio = ""
    objeto = ""
    otros = ""
    registrales = ""
    
    if "Ceses/Dimisiones." in paragraph:
        ceses = paragraph.split("Ceses/Dimisiones.")[1].split("Nombramientos.")[0].split("Ampliación de capital.")[0].split("Cambio de domicilio social.")[0].split("Cambio de objeto social.")[0].split("Otros conceptos:")[0].split("Datos registrales.")[0]
    if "Nombramientos." in paragraph:
        nombramientos = paragraph.split("Nombramientos.")[1].split("Ampliación de capital.")[0].split("Cambio de domicilio social.")[0].split("Cambio de objeto social.")[0].split("Otros conceptos:")[0].split("Datos registrales.")[0]
    if "Ampliación de capital." in paragraph:
        ampliacion = paragraph.split("Ampliación de capital.")[1].split("Cambio de domicilio social.")[0].split("Cambio de objeto social.")[0].split("Otros conceptos:")[0].split("Datos registrales.")[0]
    if "Cambio de domicilio social." in paragraph:
        domicilio = paragraph.split("Cambio de domicilio social.")[1].split("Cambio de objeto social.")[0].split("Otros conceptos:")[0].split("Datos registrales.")[0]
    if "Cambio de objeto social." in paragraph:
        objeto = paragraph.split("Cambio de objeto social.")[1].split("Otros conceptos:")[0].split("Datos registrales.")[0]
    if "Otros conceptos:" in paragraph:
        otros = paragraph.split("Otros conceptos:")[1].split("Datos registrales.")[0]
    if "Datos registrales." in paragraph:
        registrales = paragraph.split("Datos registrales.")[1]
    return ceses, nombramientos, ampliacion, domicilio, objeto, otros, registrales

# %%
for page in pdf:
    paragraph = ""
    old_id = None
    for line in page.splitlines():
        # Gets the first word of each line and checks whether it is an ID
        new_id = line.strip().split(" ")[0]
        if new_id.isdigit():
            if old_id:
                # Remove multiple spaces
                paragraph = re.sub(' +', ' ', paragraph)
                ceses, nombramientos, ampliacion, domicilio, objeto, otros, registrales = extract_concepts(paragraph)
            paragraph = ""
            name = line.split("-")[1].strip().split(".")[0]
            old_id = new_id
        else:
            paragraph =  f"{paragraph}{line}"

# %%
for page in pdf:
    paragraph = ""
    old_id = None
    for line in page.splitlines():
        # Gets the first word of each line and checks whether it is an ID
        new_id = line.strip().split(" ")[0]
        if new_id.isdigit():
            if old_id:
                # extract_concepts(paragraph)
            paragraph = ""
            name = line.split("-")[1].strip().split(".")[0]
            old_id = new_id
        else:
            paragraph =  f"{paragraph}{line}"

# %%
for page in pdf:
    for line in page.splitlines():
        print(line)
        print("--------")
# Out:
#                      BOLETÍN OFICIAL DEL REGISTRO MERCANTIL
# --------
# Núm. 232                                            Martes 3 de diciembre de 2019                                                 Pág. 53036
# --------
#                                           SECCIÓN PRIMERA
# --------
#                                                          Empresarios
# --------
#                                                           Actos inscritos
# --------
#                                                               ALBACETE
# --------
#      498053 - RESTAURACION PLAZA GOMEZ SOCIEDAD LIMITADA.
# --------
#      Otros conceptos: Declaración de insolvencia total por importe de 11.137,78 euros. Datos registrales. T 982, L 746, F 66, S 8, H AB
# --------
#      26079, I/A 2 (25.11.19).
# --------
#      498054 - MANTENIMIENTOS AGRICOLAS SOCIEDAD LIMITADA.
# --------
#      Ceses/Dimisiones. Presidente: CARREÑO GARVI RAFAEL. Cons.Del.Man: CARREÑO GARVI RAFAEL. Consejero: CARREÑO
# --------
#      GARVI RAFAEL. Cons.Del.Man: CARREÑO GARVI ANTONIO. Consejero: CARREÑO GARVI ANTONIO. Secretario: AVILES
# --------
#      CESPEDES JOSE LUIS. Cons.Del.Man: AVILES CESPEDES JOSE LUIS. Consejero: AVILES CESPEDES JOSE LUIS.
# --------
#      Nombramientos. Adm. Solid.: CARREÑO GARVI RAFAEL;CARREÑO GARVI ANTONIO;AVILES CESPEDES JOSE LUIS. Otros
# --------
#      conceptos: Cambio del Organo de Administración: Consejo de administración a Administradores solidarios. Datos registrales. T
# --------
#      638, L 402, F 182, S 8, H AB 5589, I/A 5 (25.11.19).
# --------
#      498055 - SIMETRIC PHI SOCIEDAD LIMITADA.
# --------
#      Ceses/Dimisiones. Adm. Unico: LLORENTE MERINO RAFAEL. Nombramientos. Adm. Solid.: OLIVAS NAHARRO JOSE
# --------
#      CASTO;MARTINEZ GOMEZ JOSE LUIS. Ampliación de capital. Capital: 3.000,00 Euros. Resultante Suscrito: 6.000,00 Euros.
# --------
#      Otros conceptos: Cambio del Organo de Administración: Administrador único a Administradores solidarios. Cambio de domicilio
# --------
#      social. C/ ROSARIO, 4 1º E 02001 (ALBACETE). Datos registrales. T 972, L 736, F 207, S 8, H AB 25569, I/A 2 (25.11.19).
# --------
#      498056 - CARPE GESTION SOCIEDAD LIMITADA.
# --------
#      Ceses/Dimisiones. Adm. Unico: ESPARCIA VALCARCEL CARMELO JUAN. Nombramientos. Adm. Unico: VILLALGORDO
# --------
#      VALENCIANO JOSE. Ampliación de capital. Capital: 3.140,00 Euros. Resultante Suscrito: 6.150,00 Euros. Cambio de domicilio
# --------
#      social. C/ CRISTOBAL LOZANO, 10 (HELLIN). Datos registrales. T 826, L 590, F 152, S 8, H AB 16366, I/A 3 (25.11.19).
# --------
#      498057 - CLINICAS GAVIDENT MARTINEZ LOPEZ SOCIEDAD LIMITADA.
# --------
#      Ceses/Dimisiones. Adm. Unico: MARTINEZ LOPEZ GABRIELA. Nombramientos. Adm. Unico: MARTINEZ BORJA VICENTE
# --------
#      DAMIAN. Datos registrales. T 946, L 710, F 64, S 8, H AB 24246, I/A 2 (25.11.19).
# --------
#      498058 - FAMILIA JIMENEZ IZQUIERDO SOCIEDAD LIMITADA.
# --------
#      Nombramientos. Auditor: SERRANO PEREZ PASCUAL. Aud.Supl.: FERNANDEZ DE DIEGO ARMANDO. Datos registrales. T 979,
# --------
#      L 743, F 163, S 8, H AB 22000, I/A 5 (25.11.19).
# --------
#      498059 - GRUAS LA MANCHA SIGLO XXI SOCIEDAD LIMITADA.
# --------
#      Ceses/Dimisiones. Adm. Unico: GARCIA GARCIA FRANCISCO. Nombramientos. Adm. Unico: GARCIA BAUTISTA ARANZAZU.
# --------
#      Datos registrales. T 909, L 673, F 146, S 8, H AB 13212, I/A 7 (25.11.19).
# --------
#      498060 - SERVICIOS DIVERSOS Y CONSULTORIA DE CASTILLA LA MANCHA SOCIEDAD LIMITADA.
# --------
#      Otros conceptos: Declaración de insolvencia total por importe de 33.697,51 euros. Datos registrales. T 948, L 712, F 131, S 8, H
# --------
#      AB 21925, I/A 4 (26.11.19).
# --------
#      498061 - AGRICOLA GOMEZ YAÑEZ SOCIEDAD LIMITADA.
# --------
#      Ceses/Dimisiones. Adm. Unico: RODRIGUEZ MARTINEZ CARMEN MARIA. Nombramientos. Adm. Unico: RODRIGUEZ ARCOS
# --------
#                                                                                                                                            cve: BORME-A-2019-232-02
# --------
#      MANUEL. Ampliación de capital. Capital: 38.000,00 Euros. Resultante Suscrito: 41.008,00 Euros. Datos registrales. T 952, L 716,
# --------
#      F 194, S 8, H AB 24622, I/A 4 (25.11.19).
# --------
#      498062 - LAS BEATAS CACERIAS SOCIEDAD LIMITADA.
# --------
#      Otros conceptos: Declaración de insolvencia parcial por importe de 3.959, 04 euros. Datos registrales. T 1006, L 770, F 173, S 8, H
# --------
#      AB 18132, I/A 3 (26.11.19).
# --------
#                                                                                                                                            Verificable en https://www.boe.es
# --------
#      498063 - ALBACETE INDUSTRIAL SOCIEDAD ANONIMA.
# --------
#      Situación concursal. Procedimiento concursal 336/2019. FIRME: NO, Fecha de resolución 20/09/2019. Otras. Publicación de Edicto.
# --------
#      Juzgado: num. 0 JUZGADO DE PRIMERA INSTANCIA NUMERO 3 DE ALBACETE. Juez: EVA MARTINEZ CUENCA. Resoluciones:
# --------
#      DISPONGO: 1.- Homologar el acuerdo de refinanciación suscrito por la mercantil ALBACETE INDUSTRIAL, S.A., como financiada, la
# --------
#                      BOLETÍN OFICIAL DEL REGISTRO MERCANTIL
# --------
# Núm. 232                                              Martes 3 de diciembre de 2019                                                    Pág. 53037
# --------
#      mercantil ALBACETE URBANA, S.L., como garante, y las entidades financieras BANCO SANTANDER, S.A., BANKIA, S.A., CAJAMAR
# --------
#      CAJA RURAL, SOCIEDAD COOPERATIVA DE CREDITO, LIBERBANK. Datos registrales. T 744, L 508, F 8, S 8, H AB 3004, I/A A
# --------
#      (26.11.19).
# --------
#      498064 - INSTITUTO TECNICO AGRONOMICO PROVINCIAL SOCIEDAD ANONIMA.
# --------
#      Ceses/Dimisiones. Consejero: MIRANDA MARTINEZ MANUEL;RUBIO GOMEZ MARIA FRANCISCA;DIAZ HUEDO JOSE
# --------
#      IGNACIO;GOMEZ MOROTE JUAN;BERRUGA SIMARRO CONSTANTINO. Vicepresid.: ATIENZAR NUÑEZ LUIS MIGUEL. Consejero:
# --------
#      ATIENZAR NUÑEZ LUIS MIGUEL. Presidente: MORENO CAMPAYO AGUSTIN. Con.Delegado: MORENO CAMPAYO AGUSTIN.
# --------
#      Consejero: MORENO CAMPAYO AGUSTIN;GONZALEZ MORENO ANGELA;MARTINEZ GARCIA FRANCISCO. Nombramientos.
# --------
#      Consejero: TORRES VALENCOSO AMPARO;SIERRA MORCILLO MARIA PILAR;ZAMORA SAIZ MIGUEL;BERRUGA SIMARRO
# --------
#      CONSTANTINO;ARNEDO MEJIAS CESAREA;GARCIA CORREOSO MARIA AGAPITA;DIAZ HUEDO JOSE IGNACIO;SAEZ GOMEZ
# --------
#      RAMON;GONZALEZ MORENO ANGELA. Presidente: TORRES VALENCOSO AMPARO. Vicepresid.: SIERRA MORCILLO MARIA
# --------
#      PILAR. Con.Delegado: TORRES VALENCOSO AMPARO. Reelecciones. SecreNoConsj: LOPEZ MORENO MARIA DOLORES.
# --------
#      Datos registrales. T 998, L 762, F 131, S 8, H AB 1361, I/A 42 (26.11.19).
# --------
#      498065 - SOCIEDAD AGRARIA DE TRANSFORMACION Nº 3538 PINAGA.
# --------
#      Revocaciones. Apoderado: PINA DE ILLANA FRANCISCO. Datos registrales. T 1001, L 765, F 48, S 8, H AB 8868, I/A 11
# --------
#      (26.11.19).
# --------
#      498066 - SOCIEDAD AGRARIA DE TRANSFORMACION Nº 3538 PINAGA.
# --------
#      Revocaciones. Apoderado: HERRAIZ CASTILLO PEDRO GASPAR. Datos registrales. T 1001, L 765, F 48, S 8, H AB 8868, I/A 12
# --------
#      (26.11.19).
# --------
#      498067 - SOCIEDAD AGRARIA DE TRANSFORMACION Nº 3538 PINAGA.
# --------
#      Ceses/Dimisiones. Mie.Cons.Rec: PINA ILLANA CECILIA;GARCIA CONESA JOSE;ANDUJAR TOMAS RAFAEL;PINA ILLANA
# --------
#      LUISA DAMASA. Sec.Cons.Rec: PINA ILLANA FRANCISCO. Mie.Cons.Rec: PINA ILLANA FRANCISCO. Pre.Cons.Rec: PINA ILLANA
# --------
#      MARIA MANUELA. Mie.Cons.Rec: PINA ILLANA MARIA MANUELA. Nombramientos. Pre.Cons.Rec: GARCIA FERRER ANDRES.
# --------
#      Mie.Cons.Rec: GARCIA FERRER ANDRES. Sec.Cons.Rec: GARCIA DE LIS MARIA. Mie.Cons.Rec: GARCIA DE LIS MARIA.
# --------
#      Apo.Sol.: GARCIA FERRER ANDRES;DE LIS GARCIA MARIA DE LAS MERCEDES;GARCIA DE LIS ANDRES;GARCIA DE LIS
# --------
#      MARIA. Cambio de domicilio social. AVDA JUAN GARCIA GONZALEZ, 50 (RODA (LA)). Cambio de objeto social. Producción,
# --------
#      transformación y comercialización de productos hortofrutícolas, así como la prestación de servicios comunes para tal fin, realización de
# --------
#      importantes obras de electrificación, captación de aguas subterráneas, canalizaciones, transformación de secano a regadío,
# --------
#      roturaciones, desfondes, des. Datos registrales. T 1012, L 776, F 176, S 8, H AB 8868, I/A 13 (26.11.19).
# --------
#      498068 - ALBACETE DE RECUPERACION SOCIEDAD LIMITADA.
# --------
#      Cambio de denominación social. GRUPO AMIAB MEDIO AMBIENTE SOCIEDAD LIMITADA. Datos registrales. T 994, L 758, F
# --------
#      83, S 8, H AB 21075, I/A 5 (26.11.19).
# --------
#      498069 - TECNICAS AVANZADAS VILLARROBLEDO SOCIEDAD LIMITADA.
# --------
#      Nombramientos. Apoderado: GUTIERREZ GARCIA CARLOS. Datos registrales. T 1012, L 776, F 30, S 8, H AB 27822, I/A 2
# --------
#      (26.11.19).
# --------
#      498070 - CASARGA SOCIEDAD ANONIMA.
# --------
#      Ceses/Dimisiones. Presidente: PEREZ MORENO JOSE. Cons.Del.Man: PEREZ MORENO JOSE. Consejero: PEREZ MORENO
# --------
#      JOSE. Secretario: POVEDA AGUADO MARIA DE LOS ANGELES. Nombramientos. Cons.Del.Man: POVEDA AGUADO MARIA DE
# --------
#      LOS ANGELES. Presidente: POVEDA AGUADO MARIA DE LOS ANGELES. Secretario: PEREZ POVEDA JOSE MANUEL. Datos
# --------
#      registrales. T 728, L 492, F 169, S 8, H AB 1886, I/A 8 (26.11.19).
# --------
#      498071 - AUTOMATIZACION Y DISEÑO INDUSTRIAL SOCIEDAD LIMITADA.
# --------
#      Reelecciones. Auditor: AEC AUDITORES SOCIEDAD LIMITADA PROFESIONAL. Datos registrales. T 949, L 713, F 97, S 8, H AB
# --------
#      8465, I/A 13 (26.11.19).
# --------
#      498072 - LADDER BUSINESS SOCIEDAD LIMITADA.
# --------
#                                                                                                                                                 cve: BORME-A-2019-232-02
# --------
#      Ceses/Dimisiones. Adm. Unico: GARCIA RODRIGUEZ IVAN. Liquidador: GARCIA RODRIGUEZ IVAN. Nombramientos.
# --------
#      Liquidador: GARCIA RODRIGUEZ IVAN. Disolución. Voluntaria. Extinción. Datos registrales. T 805, L 569, F 194, S 8, H AB
# --------
#      15205, I/A 5 (26.11.19).
# --------
#      498073 - SANCHEZ AUÑON SOCIEDAD LIMITADA.
# --------
#      Constitución. Comienzo de operaciones: 7.11.19. Objeto social: Arrendamiento de bienes inmuebles -CNAE: 6820-. Domicilio: C/
# --------
#                                                                                                                                                 Verificable en https://www.boe.es
# --------
#      DOCTOR TABERA Y ARAOZ, 21 Bajo (HELLIN). Capital: 60.000,00 Euros. Nombramientos. Adm. Mancom.: SANCHEZ INIESTA
# --------
#      CARLOS ANDRES;MARTINEZ AUÑON ANTONIO. Datos registrales. T 1012, L 776, F 181, S 8, H AB 27858, I/A 1 (26.11.19).
# --------
#                        BOLETÍN OFICIAL DEL REGISTRO MERCANTIL
# --------
# Núm. 232                                            Martes 3 de diciembre de 2019                                               Pág. 53038
# --------
#       498074 - MINAYENSE ELIJOA SOCIEDAD LIMITADA.
# --------
#       Constitución. Comienzo de operaciones: 26.11.19. Objeto social: Actividad Principal: 7739 Alquiler de otra maquinaria, equipos y
# --------
#       bienes tangibles. Domicilio: C/ MARIA MARIN, 76 02003 (ALBACETE). Capital: 31.000,00 Euros. Nombramientos. Adm. Solid.:
# --------
#       CONCHIÑA GONZALEZ ELISABETH;CONCHINA GONZALEZ JOAQUIN. Datos registrales. T 1012, L 776, F 188, S 8, H AB 27861,
# --------
#       I/A 1 (26.11.19).
# --------
#                                                                                                                                          cve: BORME-A-2019-232-02
# --------
#                                                                                                                                          Verificable en https://www.boe.es
# --------
#   https://www.boe.es                          BOLETÍN OFICIAL DEL REGISTRO MERCANTIL                  D.L.: M-5188/1990 - ISSN: 0214-9958
# --------

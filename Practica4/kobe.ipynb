# %%
import json

def load_json(path):
    """
    Loads JSON file in given path into a dictionary that will
    be returned.
    
    Params
    -------
    path : str
        The path to the target JSON file.

    Return
    -------
    d : dic
        The dictionary with the JSON content loaded.
    """
    with open(path, "r") as input_file:
        d = json.load(input_file)
    return d

d = load_json(r"C:\Users\Maria\github\ATD\Practica4\kobe.json")

# %%
# Cogemos los datos de la temporada regular
d['resultSets'][0]['rowSet']
# Out:
# [[977,
#   '1996-97',
#   '00',
#   1610612747,
#   'LAL',
#   18.0,
#   71,
#   6,
#   15.5,
#   2.5,
#   5.9,
#   0.417,
#   0.7,
#   1.9,
#   0.375,
#   1.9,
#   2.3,
#   0.819,
#   0.7,
#   1.2,
#   1.9,
#   1.3,
#   0.7,
#   0.3,
#   1.6,
#   1.4,
#   7.6],
#  [977,
#   '1997-98',
#   '00',
#   1610612747,
#   'LAL',
#   19.0,
#   79,
#   1,
#   26.0,
#   4.9,
#   11.6,
#   0.428,
#   0.9,
#   2.8,
#   0.341,
#   4.6,
#   5.8,
#   0.794,
#   1.0,
#   2.1,
#   3.1,
#   2.5,
#   0.9,
#   0.5,
#   2.0,
#   2.3,
#   15.4],
#  [977,
#   '1998-99',
#   '00',
#   1610612747,
#   'LAL',
#   20.0,
#   50,
#   50,
#   37.9,
#   7.2,
#   15.6,
#   0.465,
#   0.5,
#   2.0,
#   0.267,
#   4.9,
#   5.8,
#   0.839,
#   1.1,
#   4.2,
#   5.3,
#   3.8,
#   1.4,
#   1.0,
#   3.1,
#   3.1,
#   19.9],
#  [977,
#   '1999-00',
#   '00',
#   1610612747,
#   'LAL',
#   21.0,
#   66,
#   62,
#   38.2,
#   8.4,
#   17.9,
#   0.468,
#   0.7,
#   2.2,
#   0.319,
#   5.0,
#   6.1,
#   0.821,
#   1.6,
#   4.7,
#   6.3,
#   4.9,
#   1.6,
#   0.9,
#   2.8,
#   3.3,
#   22.5],
#  [977,
#   '2000-01',
#   '00',
#   1610612747,
#   'LAL',
#   22.0,
#   68,
#   68,
#   41.0,
#   10.3,
#   22.2,
#   0.464,
#   0.9,
#   2.9,
#   0.305,
#   7.0,
#   8.2,
#   0.853,
#   1.5,
#   4.3,
#   5.9,
#   5.0,
#   1.7,
#   0.6,
#   3.2,
#   3.3,
#   28.5],
#  [977,
#   '2001-02',
#   '00',
#   1610612747,
#   'LAL',
#   23.0,
#   80,
#   80,
#   38.3,
#   9.4,
#   20.0,
#   0.469,
#   0.4,
#   1.7,
#   0.25,
#   6.1,
#   7.4,
#   0.829,
#   1.4,
#   4.1,
#   5.5,
#   5.5,
#   1.5,
#   0.4,
#   2.8,
#   2.9,
#   25.2],
#  [977,
#   '2002-03',
#   '00',
#   1610612747,
#   'LAL',
#   24.0,
#   82,
#   82,
#   41.5,
#   10.6,
#   23.5,
#   0.451,
#   1.5,
#   4.0,
#   0.383,
#   7.3,
#   8.7,
#   0.843,
#   1.3,
#   5.6,
#   6.9,
#   5.9,
#   2.2,
#   0.8,
#   3.5,
#   2.7,
#   30.0],
#  [977,
#   '2003-04',
#   '00',
#   1610612747,
#   'LAL',
#   25.0,
#   65,
#   64,
#   37.7,
#   7.9,
#   18.1,
#   0.438,
#   1.1,
#   3.3,
#   0.327,
#   7.0,
#   8.2,
#   0.852,
#   1.6,
#   3.9,
#   5.5,
#   5.1,
#   1.7,
#   0.4,
#   2.6,
#   2.7,
#   24.0],
#  [977,
#   '2004-05',
#   '00',
#   1610612747,
#   'LAL',
#   26.0,
#   66,
#   66,
#   40.7,
#   8.7,
#   20.1,
#   0.433,
#   2.0,
#   5.9,
#   0.339,
#   8.2,
#   10.1,
#   0.816,
#   1.4,
#   4.5,
#   5.9,
#   6.0,
#   1.3,
#   0.8,
#   4.1,
#   2.6,
#   27.6],
#  [977,
#   '2005-06',
#   '00',
#   1610612747,
#   'LAL',
#   27.0,
#   80,
#   80,
#   41.0,
#   12.2,
#   27.2,
#   0.45,
#   2.3,
#   6.5,
#   0.347,
#   8.7,
#   10.2,
#   0.85,
#   0.9,
#   4.4,
#   5.3,
#   4.5,
#   1.8,
#   0.4,
#   3.1,
#   2.9,
#   35.4],
#  [977,
#   '2006-07',
#   '00',
#   1610612747,
#   'LAL',
#   28.0,
#   77,
#   77,
#   40.8,
#   10.6,
#   22.8,
#   0.463,
#   1.8,
#   5.2,
#   0.344,
#   8.7,
#   10.0,
#   0.868,
#   1.0,
#   4.7,
#   5.7,
#   5.4,
#   1.4,
#   0.5,
#   3.3,
#   2.7,
#   31.6],
#  [977,
#   '2007-08',
#   '00',
#   1610612747,
#   'LAL',
#   29.0,
#   82,
#   82,
#   38.9,
#   9.5,
#   20.6,
#   0.459,
#   1.8,
#   5.1,
#   0.361,
#   7.6,
#   9.0,
#   0.84,
#   1.1,
#   5.2,
#   6.3,
#   5.4,
#   1.8,
#   0.5,
#   3.1,
#   2.8,
#   28.3],
#  [977,
#   '2008-09',
#   '00',
#   1610612747,
#   'LAL',
#   30.0,
#   82,
#   82,
#   36.1,
#   9.8,
#   20.9,
#   0.467,
#   1.4,
#   4.1,
#   0.351,
#   5.9,
#   6.9,
#   0.856,
#   1.1,
#   4.1,
#   5.2,
#   4.9,
#   1.5,
#   0.5,
#   2.6,
#   2.3,
#   26.8],
#  [977,
#   '2009-10',
#   '00',
#   1610612747,
#   'LAL',
#   31.0,
#   73,
#   73,
#   38.8,
#   9.8,
#   21.5,
#   0.456,
#   1.4,
#   4.1,
#   0.329,
#   6.0,
#   7.4,
#   0.811,
#   1.1,
#   4.3,
#   5.4,
#   5.0,
#   1.5,
#   0.3,
#   3.2,
#   2.6,
#   27.0],
#  [977,
#   '2010-11',
#   '00',
#   1610612747,
#   'LAL',
#   32.0,
#   82,
#   82,
#   33.9,
#   9.0,
#   20.0,
#   0.451,
#   1.4,
#   4.3,
#   0.323,
#   5.9,
#   7.1,
#   0.828,
#   1.0,
#   4.1,
#   5.1,
#   4.7,
#   1.2,
#   0.1,
#   3.0,
#   2.1,
#   25.3],
#  [977,
#   '2011-12',
#   '00',
#   1610612747,
#   'LAL',
#   33.0,
#   58,
#   58,
#   38.5,
#   9.9,
#   23.0,
#   0.43,
#   1.5,
#   4.9,
#   0.303,
#   6.6,
#   7.8,
#   0.845,
#   1.1,
#   4.3,
#   5.4,
#   4.6,
#   1.2,
#   0.3,
#   3.5,
#   1.8,
#   27.9],
#  [977,
#   '2012-13',
#   '00',
#   1610612747,
#   'LAL',
#   34.0,
#   78,
#   78,
#   38.6,
#   9.5,
#   20.4,
#   0.463,
#   1.7,
#   5.2,
#   0.324,
#   6.7,
#   8.0,
#   0.839,
#   0.8,
#   4.7,
#   5.6,
#   6.0,
#   1.4,
#   0.3,
#   3.7,
#   2.2,
#   27.3],
#  [977,
#   '2013-14',
#   '00',
#   1610612747,
#   'LAL',
#   35.0,
#   6,
#   6,
#   29.5,
#   5.2,
#   12.2,
#   0.425,
#   0.5,
#   2.7,
#   0.188,
#   3.0,
#   3.5,
#   0.857,
#   0.3,
#   4.0,
#   4.3,
#   6.3,
#   1.2,
#   0.2,
#   5.7,
#   1.5,
#   13.8],
#  [977,
#   '2014-15',
#   '00',
#   1610612747,
#   'LAL',
#   36.0,
#   35,
#   35,
#   34.5,
#   7.6,
#   20.4,
#   0.373,
#   1.5,
#   5.3,
#   0.293,
#   5.6,
#   6.9,
#   0.813,
#   0.7,
#   4.9,
#   5.7,
#   5.6,
#   1.3,
#   0.2,
#   3.7,
#   1.9,
#   22.3],
#  [977,
#   '2015-16',
#   '00',
#   1610612747,
#   'LAL',
#   37.0,
#   66,
#   66,
#   28.2,
#   6.0,
#   16.9,
#   0.358,
#   2.0,
#   7.1,
#   0.285,
#   3.5,
#   4.3,
#   0.826,
#   0.6,
#   3.1,
#   3.7,
#   2.8,
#   0.9,
#   0.2,
#   2.0,
#   1.7,
#   17.6]]

# %%
# Cogemos los datos de la temporada regular
# y la trasponemos para que sea más sencillo acceder a los elementos necesarios
regular_season_stats = ["AÑO DE LA TEMPORADA", "EDAD DEL JUGADOR", "PARTIDOS DISPUTADOS", "MEDIA DE PUNTOS ANOTADOS", "MEDIA DE ASISTENCIAS REPARTIDAS", "MEDIA DE REBOTES RECOGIDOS"]
a =list(zip(*d['resultSets'][0]['rowSet']))
b = [list(a[1]), list(a[5]), list(a[6]), list(a[-1]), list(a[-6]), list(a[13])]
#c = list(zip(*b))
c = list(map(list, zip(*b)))
#print(c)

# print(regular_season_stats)
regular_season_stats = +



regular_season_stats
print(regular_season_stats)
# Out:
# [['1996-97', 18.0, 71, 7.6, 1.3, 1.9], ['1997-98', 19.0, 79, 15.4, 2.5, 2.8], ['1998-99', 20.0, 50, 19.9, 3.8, 2.0], ['1999-00', 21.0, 66, 22.5, 4.9, 2.2], ['2000-01', 22.0, 68, 28.5, 5.0, 2.9], ['2001-02', 23.0, 80, 25.2, 5.5, 1.7], ['2002-03', 24.0, 82, 30.0, 5.9, 4.0], ['2003-04', 25.0, 65, 24.0, 5.1, 3.3], ['2004-05', 26.0, 66, 27.6, 6.0, 5.9], ['2005-06', 27.0, 80, 35.4, 4.5, 6.5], ['2006-07', 28.0, 77, 31.6, 5.4, 5.2], ['2007-08', 29.0, 82, 28.3, 5.4, 5.1], ['2008-09', 30.0, 82, 26.8, 4.9, 4.1], ['2009-10', 31.0, 73, 27.0, 5.0, 4.1], ['2010-11', 32.0, 82, 25.3, 4.7, 4.3], ['2011-12', 33.0, 58, 27.9, 4.6, 4.9], ['2012-13', 34.0, 78, 27.3, 6.0, 5.2], ['2013-14', 35.0, 6, 13.8, 6.3, 2.7], ['2014-15', 36.0, 35, 22.3, 5.6, 5.3], ['2015-16', 37.0, 66, 17.6, 2.8, 7.1], 'AÑO DE LA TEMPORADA', 'EDAD DEL JUGADOR', 'PARTIDOS DISPUTADOS', 'MEDIA DE PUNTOS ANOTADOS', 'MEDIA DE ASISTENCIAS REPARTIDAS', 'MEDIA DE REBOTES RECOGIDOS']

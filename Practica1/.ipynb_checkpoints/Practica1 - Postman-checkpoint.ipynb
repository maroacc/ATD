# %%
# PRÁCTICA 1 - Postman
# María José Medina Hernández

# %%
# Imports
import requests

# %%
location = "40.429562,-3.711455"
radius = 1000
_type = "bar"
# api_key =

# %%
url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={location}&radius={radius}&type={_type}&key={api_key}"

payload={}
headers = {}

# %%
response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#    "html_attributions" : [],
#    "next_page_token" : "Aap_uECZ-QRmWotzFqsNJ_wU0CGG4IPzI-I7Oh2gxZFH3hKUNO8iImHjNu0S6EKOjk84LRNS-6KB7Ymt79dpucH21Qa7QoD-A_5k36hUCGxqidSXd7twESOLY54XPwsQC2F4pY3FocQKjMMqAT2okZZqi_mIH2NN3j9dh8NpSd6lrK3GT6NcCEoTfvIffeTMrTnDu0HwH6Sa7vQ8e8NIEJeuTNfjxJH8fKR4ujI3liPGkCusJMOOTDWM3jfEDDzbrgeZ0gqBuVfDlmJRM44Zz_UWaWn4tBmA1c-h9ggiNlQekEFkPJ_1LH9oc0gDh8X6VwBHxkEx8v4jgPIdACqhqy6aSSIyUDGlO3DA6ilbIokd4AstVOholXMcuZ4IN-1RDzGW-tsC1ZMW5o_bSXv-cnRLL11xfgEwMU8kNORLAftCBzZk6W1de6Y",
#    "results" : [
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 40.4248954,
#                "lng" : -3.7129334
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 40.4262221802915,
#                   "lng" : -3.711638069708497
#                },
#                "southwest" : {
#                   "lat" : 40.42352421970851,
# ...

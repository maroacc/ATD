# %%
# PRÁCTICA 14 - Parser
# María José Medina Hernández

# %%
# !pip3 install pdftotext
# Out:
# ...
#   Using cached pdftotext-2.2.2.tar.gz (113 kB)
# ...
#   Running setup.py clean for pdftotext
# Failed to build pdftotext
# ...
#     Running setup.py install for pdftotext: started
#     Running setup.py install for pdftotext: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Maria\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Maria\\AppData\\Local\\Temp\\pip-install-0yemttd7\\pdftotext_438915df4cef412f8cc16db25f67e247\\setup.py'"'"'; __file__='"'"'C:\\Users\\Maria\\AppData\\Local\\Temp\\pip-install-0yemttd7\\pdftotext_438915df4cef412f8cc16db25f67e247\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\Maria\AppData\Local\Temp\pip-wheel-3gjrdydr'
# ...
